# %% [markdown]
# ### 矩阵运算

# %%
import numpy as np

# %%
x = np.array([5,5])
y = np.array([2,2])

# %%
x = np.array([5,5])
y = np.array([2,4])

# %%
np.multiply(x,y)
# Out:
# array([10, 10])

# %% [markdown]
# 数组对应位置分别做乘法

# %%
np.dot(x,y)
# Out:
# np.int64(20)

# %% [markdown]
# 矩阵相乘

# %%
x.shape
# Out:
# (2,)

# %%
y.shape
# Out:
# (2,)

# %%
x.shape = 2,1

# %%
x
# Out:
# array([[5],
#        [5]])

# %%
np.dot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.dot(x,y)
#
# ValueError: shapes (2,1) and (2,) not aligned: 1 (dim 1) != 2 (dim 0)

# %% [markdown]
# 只有维度一样才能进行计算（m x n与n x p）

# %%
y.shape = 1,2
y
# Out:
# array([[2, 2]])

# %%
x
# Out:
# array([[5],
#        [5]])

# %%
print (x.shape)
print (y.shape)
# Out:
# (2, 1)
# (1, 2)

# %%
np.dot(x,y)
# Out:
# array([[10, 10],
#        [10, 10]])

# %%
np.dot(y,x)
# Out:
# array([[20]])

# %%
x = np.array([1,1,1])
y = np.array([[1,2,3],[4,5,6]])
print (x * y)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
z = y.T
z
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.dot(x,z)
# Out:
# array([ 6, 15])

# %%
y = np.array([1,1,1,4])
x = np.array([1,1,1,2])
x == y
# Out:
# array([ True,  True,  True, False])

# %% [markdown]
# 对应每个位置进行判断

# %%
np.logical_and(x,y)
# Out:
# array([ True,  True,  True,  True])

# %% [markdown]
# 与操作，两个都是True（！= 0）即返回True

# %%
np.logical_or(x,y)
# Out:
# array([ True,  True,  True,  True])

# %%
np.logical_not(x,y)
# Out:
# array([0, 0, 0, 0])

# %% [markdown]
# 与或非
